# %%
"""
Q1. What is Flask Framework? What are the advantages of Flask Framework?

Ans:flask framework is module that lets you develop web application easily.

Advantages of flask
1. scalable: it is micro framework means that you can use it to grow a tech project such as web app incredibly quickly.
2. Flexible : This is easily rearraned and moved around.
3. Lightweight: flask supports modular programming which its functionality can be split into several interchangeable modules,
                and each module acts as an independent building block.
4. Documentation: flask users will find a healthy number of example and tips arranges in a structred manner. this encourages developers to use the framework.
""""

# %%
"""
Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook.

Ans:
"""
from flask import Flask
obj=Flask(__name__)

@obj.route('/')
def display_hello():
    return "<h1>Hello world<h1>"

if __name__=="__main__":
    obj.run(host='0.0.0.0')

# %% [markdown]
# ![Screenshot (17).png](attachment:04e66203-9244-4900-b96e-50029f20bcb1.png)

# %%
"""
Q3. What is App routing in Flask? Why do we use app routes?

Ans: App routing means mapping the url to specific fuction that will handle the logic for that url.
    
     we use app routes to map the specific URL with associated function that is intended to perfome some 
     task.
    """

# %%
"""
Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999
"""

Ans: 
from flask import Flask
 
obj=Flask(__name__)

@obj.route('/welcome')
def wel_come_message():
    return "<h1>Hello To ABC coporations<h1>"

@obj.route('/')
def company_details():
    company_name='ABC coporations'
    Location ='India'
    contact_details='999-999-999'
    return "comany details: {},{},{}".format(company_name,Location,contact_details)
    
if __name__=='__main__':
    obj.run(host='0.0.0.0')

# %% [markdown]
# ![Screenshot (18).png](attachment:86ace7d4-624d-4bc3-9229-3c9b35d53682.png)

# %% [markdown]
# ![Screenshot (19).png](attachment:c447bf6c-1ecc-44eb-905b-f2eacd462767.png)

# %%
"""
Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.

ANS: url_for() is used in flask for url building.
