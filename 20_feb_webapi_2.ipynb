# %%
"""
Q1. Explain GET and POST methods.

Ans: These get and post method are used to transfer data from client to server in HTTTP  protocol.

GET method 
1. Get method is that get carries request parameter appended in URL string.
2. get request is not secured because data is exposed in URL bar.
3. get request is more efficient and used more than post.
4. get request can be bookmarked.

POST method: 
1. post carries request parameter in message body.
2. post request is secured because is not exposed in URL bar.
3. post request is less efficient and used less than get.
4. post request cannot be bookmarked.

""""

# %%
"""
Q2. Why is request used in Flask?

Ans: reuest is used to send the data form client to server.

# %%
"""
Q3. Why is redirect() used in Flask?

Ans:  redirect() function allows developers to redirect users to specified URL and
      assign a specifies status code.

# %%
"""
Q4. What are templates in Flask? Why is the render_template() function used?

Ans: Templates are files that contain static data as well as placeholder for dynamic data.
     
     render_template(): is used to generate output from a template file basef on the jinja2 engine that found in the applicatio templates folder.

# %%
"""
Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

Ans: 
"""
from flask import Flask
from flask import request
 
obj=Flask(__name__)

@obj.route('/well')
def simple_api():
    data=request.args.get('a')
    return "Hello this is {}".format(data)


if __name__=='__main__':
    obj.run(host='0.0.0.0')

# %% [markdown]
# ![Screenshot (20).png](attachment:cb0c5910-bfec-4f90-9f4b-7915c46a3410.png)
